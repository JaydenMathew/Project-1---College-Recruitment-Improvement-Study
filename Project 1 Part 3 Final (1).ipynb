# %% [markdown]
# ### Jayden Mathew
#
# ### 3/5/2024
#
# ### Project 1 Part 3 Final
#
# ### Purpose: To illustrate and analyze data that shows trends of non-major students taking computing classes at CCM.

# %% [markdown]
# Student Questions:
#
# 1. Based on the data from question 7, which major or degree program do the majority of the non-computing majors taking a computing course come from?
#
# 2. For all respondents who answered with a 4 or 5 for question number 9, what specific class or area of computer science are they interested in taking?
#
# Teacher Questions:
#
# 1. Compare the age demographics of the different classes who answered the survey. Are there any significant differences?
#
# 2. Which factors influenced students to attend CCM? Show a bar chart of this field, sort from highest to lowest.

# %% [markdown]
# ##### Import Pandas to Jupyter Notebook (renaming as pd for easier use)

# %%
import pandas as pd

# %% [markdown]
# #### Read the CSV file into the notebook, saving it under df for easier use)

# %%
datafile = "results2023.csv"

df = pd.read_csv(datafile)

# %% [markdown]
# #### Taking a sample of the datafile shows one row and a set number of columns.
# #### By doing this, a glimpse of the unedited but formatted datafile is shown.

# %%
df.sample()
# Out:
#                     Timestamp Which course are you currently enrolled in?  \
# 71  2023/09/15 9:24:48 PM EST       CMP 101 Computer Information Literacy
#
#    How did you hear about County College of Morris? [CCM Web site]  \
# 71                                                 No
#
#    How did you hear about County College of Morris? [Social Media]  \
# 71                                                 No
#
#    How did you hear about County College of Morris? [Community Event]  \
# 71                                                 No
#
#    How did you hear about County College of Morris? [Family member or friend]  \
# 71                                                 No
#
#    How did you hear about County College of Morris? [Current CCM student]  \
# 71                                                 No
#
#    How did you hear about County College of Morris? [CCM Alumni]  \
# 71                                                 No
#
# ...

# %% [markdown]
# #### This function shows the first few entries of the datafile

# %%
df.head()
# Out:
#                     Timestamp   Which course are you currently enrolled in?  \
# 0   2023/09/05 9:36:31 PM EST         CMP 101 Computer Information Literacy
# 1   2023/09/05 9:42:31 PM EST         CMP 101 Computer Information Literacy
# 2  2023/09/05 10:00:08 PM EST         CMP 101 Computer Information Literacy
# 3  2023/09/05 11:12:17 PM EST  CMP 126 Computer Technology and Applications
# 4  2023/09/05 11:56:29 PM EST  CMP 126 Computer Technology and Applications
#
#   How did you hear about County College of Morris? [CCM Web site]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                 No
#
#   How did you hear about County College of Morris? [Social Media]  \
# 0                                                 No
# ...

# %% [markdown]
# #### This function shows the last few entries of the datafile

# %%
df.tail()
# Out:
#                       Timestamp  Which course are you currently enrolled in?  \
# 100   2023/09/19 6:04:34 PM EST  CMP 135 Computer Concepts with Applications
# 101   2023/09/19 6:05:55 PM EST        CMP 101 Computer Information Literacy
# 102   2023/09/19 6:07:54 PM EST  CMP 135 Computer Concepts with Applications
# 103   2023/09/19 6:08:11 PM EST  CMP 135 Computer Concepts with Applications
# 104  2023/09/19 10:44:14 PM EST  CMP 135 Computer Concepts with Applications
#
#     How did you hear about County College of Morris? [CCM Web site]  \
# 100                                                 No
# 101                                                Yes
# 102                                                Yes
# 103                                                Yes
# 104                                       Don't recall
#
#     How did you hear about County College of Morris? [Social Media]  \
# 100                                                 No
# ...

# %% [markdown]
# #### This function provides a brief summary of the datafile including factors such as: data types, columns, etc.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 96 columns):
#  #   Column                                                                                                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                           --------------  -----
#  0   Timestamp                                                                                                                                                                                                                                                        105 non-null    object
# ...

# %% [markdown]
# #### This function provides a description of a part of the datafile that utilizes numerical values. The descriptions explain the different aspects (such as mean, count, and max) of those values

# %%
df.describe()
# Out:
#        On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?
# count                                         105.000000
# mean                                            2.495238
# std                                             1.136152
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             3.000000
# max                                             5.000000

# %% [markdown]
# #### This function counts the number of valid values (not empty values) found for each row/column

# %%
df.count()
# Out:
# Timestamp                                                                                                                                    105
# Which course are you currently enrolled in?                                                                                                  105
# How did you hear about County College of Morris? [CCM Web site]                                                                              105
# How did you hear about County College of Morris? [Social Media]                                                                              105
# How did you hear about County College of Morris? [Community Event]                                                                           105
#                                                                                                                                             ...
# ...

# %% [markdown]
# #### This function displays how many rows and columns are found within the datafile using the following display: (rows, columns)

# %%
df.shape
# Out:
# (105, 96)

# %% [markdown]
# #### This function explains the different type of data types (ints, bool, objects, floats, etc.) found within the values for a certain column. Columns usually share the same data type throughout their values

# %%
df.dtypes
# Out:
# Timestamp                                                                                                                                    object
# Which course are you currently enrolled in?                                                                                                  object
# How did you hear about County College of Morris? [CCM Web site]                                                                              object
# How did you hear about County College of Morris? [Social Media]                                                                              object
# How did you hear about County College of Morris? [Community Event]                                                                           object
#                                                                                                                                               ...
# ...

# %% [markdown]
# #### This function displas all the column names that are present within the datafile

# %%
df.columns
# Out:
# Index(['Timestamp', 'Which course are you currently enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %% [markdown]
# #### This function removes the unneeded columns (columns that do not aid in answering the data questions) and saves them to a new variable that can be further altered.

# %%
df1 = df.drop(columns=['Timestamp', 'How did you hear about County College of Morris? [CCM Web site]', 'How did you hear about County College of Morris? [Social Media]', 'How did you hear about County College of Morris? [Community Event]', 'How did you hear about County College of Morris? [Family member or friend]', 'How did you hear about County College of Morris? [Current CCM student]', 'How did you hear about County College of Morris? [CCM Alumni]', 'How did you hear about County College of Morris? [High School Teacher]', 'How did you hear about County College of Morris? [High School Counselor]', 'How did you hear about County College of Morris? [In-app advertisement]', 'How did you hear about County College of Morris? [Employer]', 'How did you hear about County College of Morris? [Billboard]', 'How did you hear about County College of Morris? [Television]', 'How did you hear about County College of Morris? [Radio]', 'How did you hear about County College of Morris? [Home mailer]', 'How did you hear about County College of Morris? [Other]', 'Gender', 'Race/ethnicity', 'What motivated you to seek a computing class at CCM? [To keep current in computing skills]','What motivated you to seek a computing class at CCM? [Curiosity]','What motivated you to seek a computing class at CCM? [Personal Enrichment]','What motivated you to seek a computing class at CCM? [Career Advancement]','What motivated you to seek a computing class at CCM? [Career Change]','What motivated you to seek a computing class at CCM? [Professional Development]','What motivated you to seek a computing class at CCM? [Job Displacement]','What motivated you to seek a computing class at CCM? [Financial]','What motivated you to seek a computing class at CCM? [Relocation]','What motivated you to seek a computing class at CCM? [IT Industry Certifications]','What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Titans Tuesday (Virtual) Information Session]', 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Women Who Dare]', 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Regional College Fair]', 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [HS Sharetime Information Session]', 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Challenger Program]','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [CyberSecurity Information Protection Program Participation ]','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Information Session at my high school]','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit with my high school]','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit (individual)]','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Workforce Development class]','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Corporate Training]','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Teen Arts Festival]','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Summer camp at CCM]','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Hour of Code]','To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing class]','To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing related club]','To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Computing-related competitions (e.g., Robotics competition, Lego competition, Cybersecurity, Programming)]','To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Afterschool computing-related camp/program]','To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Summer computing related camp/program]','To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [An AP computing class]','To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [A dual enrollment computing class]','To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend influence]','To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend working in the computing field]','To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [High school teacher or guidance counselor]','To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Employer influence]','To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [CCM faculty member]','To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [CCM advisor/counselor]','Did you receive information about CCM computing classes from any of the following sources? [High school guidance counselor]','Did you receive information about CCM computing classes from any of the following sources? [High School Teacher]','Did you receive information about CCM computing classes from any of the following sources? [CCM Information Technologies Website]','Did you receive information about CCM computing classes from any of the following sources? [CCM Admissions]','Did you receive information about CCM computing classes from any of the following sources? [CCM advisor/counselor]','Did you receive information about CCM computing classes from any of the following sources? [Employer]','Did you receive information about CCM computing classes from any of the following sources? [CCM Workforce Development]','Did you receive information about CCM computing classes from any of the following sources? [NJ Workforce Development Program]','Did you receive information about CCM computing classes from any of the following sources? [Other]'])

# %% [markdown]
# #### This function renames different columns so that they are easier to understand and utilize. It was then saved to a new variable in case of additional changes.

# %%
df2 = df1.rename(columns = {'Which course are you currently enrolled in?':'Current Class', 'To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]':'FACTOR: COST','To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]': 'FACTOR: LOCATION','To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]':'FACTOR: PROGRAM', 'To what extent did the following impact your decision to attend County College of Morris? [Online offerings]':'FACTOR: ONLINE', 'To what extent did the following impact your decision to attend County College of Morris? [Family/friend referral]':'FACTOR: REFERRAL','To what extent did the following impact your decision to attend County College of Morris? [Faculty/staff]':'FACTOR: STAFF','To what extent did the following impact your decision to attend County College of Morris? [College reputation]':'FACTOR: COLLEGE REPUTATION','To what extent did the following impact your decision to attend County College of Morris? [Financial Aid]':'FACTOR: FINANCIAL AID','To what extent did the following impact your decision to attend County College of Morris? [Scholarships]':'FACTOR: SCHOLARSHIPS','To what extent did the following impact your decision to attend County College of Morris? [Small class sizes]':'FACTOR: CLASS SIZE (S)','To what extent did the following impact your decision to attend County College of Morris? [Extra-curricular opportunities]':'FACTOR: OPPORTUNITY','To what extent did the following impact your decision to attend County College of Morris? [Accepted my transfer credits]':'FACTOR: TRANSFERING IN','To what extent did the following impact your decision to attend County College of Morris? [Negative experience at another college]':'FACTOR: PAST NEGATIVE EXPERIENCE','To what extent did the following impact your decision to attend County College of Morris? [NJ Stars Program]':'FACTOR: NJ STARS','To what extent did the following impact your decision to attend County College of Morris? [Ability to transfer CCM credits to a 4-year school]':'FACTOR: TRANSFERING OUT','To what extent did the following impact your decision to attend County College of Morris? [Get college credit while in high school]':'FACTOR: CREDIT IN HIGHSCHOOL', 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]':'EVENT: OPEN HOUSE','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]':'EVENT: INSTANT DECISION DAY', 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]':'EVENT: ON-CAMPUS INFO. SESSION', 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Titans Tuesday (Virtual) Information Session]':'EVENT: VIRTUAL INFO. SESSION',  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Women Who Dare]':'EVENT: WOMEN WHO DARE',  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Regional College Fair]':'EVENT: REGIONAL FAIR', 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [HS Sharetime Information Session]':'EVENT: HS SHARETIME SESSION', 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Challenger Program]':'EVENT: CHALLENGER PROGRAM','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [CyberSecurity Information Protection Program Participation ]':'EVENT: CYBERSECURITY','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Information Session at my high school]':'EVENT: HS INFO. SESSION','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit with my high school]':'EVENT: HS VISIT','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit (individual)]':'INDIVIDUAL VISIT', 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Workforce Development class]':'EVENT: WORKFORCE DEVELOPMENT CLUB','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Corporate Training]':'EVENT: CORPORATE TRAINING','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Teen Arts Festival]':'EVENT: TEEN ARTS FESTIVAL','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Summer camp at CCM]':'EVENT: SUMMER CAMP','Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Hour of Code]':'EVENT: HOUR OF CODE', 'On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?':'CONTINUED INTEREST (1-5)', 'If you answered that you were interested in taking more computing classes, which ones interest you most? [Web Development]':'INTEREST: WEB DEVELOPMENT', 'If you answered that you were interested in taking more computing classes, which ones interest you most? [CyberSecurity]':'INTEREST: CYBERSECURITY', 'If you answered that you were interested in taking more computing classes, which ones interest you most? [App Development]':'INTEREST: APP DEVELOPMENT', 'If you answered that you were interested in taking more computing classes, which ones interest you most? [Data Analytics]':'INTEREST: DATA ANALYTICS', 'If you answered that you were interested in taking more computing classes, which ones interest you most? [Machine Learning/Artificial Intelligence]':'INTEREST: ARTIFICIAL INTELLIGENCE', 'If you answered that you were interested in taking more computing classes, which ones interest you most? [Computer Programming]':'INTEREST: COMPUTER PROGRAMMING', 'If you answered that you were interested in taking more computing classes, which ones interest you most? [Game Design]':'INTEREST: GAME DESIGN', 'If you answered that you were interested in taking more computing classes, which ones interest you most? [Hardware Installation & Repair]':'INTEREST: HARDWARE INSTALLATION & REPAIR', 'What degree program are you currently enrolled in?':'DEGREE/PROGRAM','Age ':'Age'})

# %%
df2.head()
# Out:
#                                   Current Class FACTOR: COST FACTOR: LOCATION  \
# 0         CMP 101 Computer Information Literacy  High Impact      Some Impact
# 1         CMP 101 Computer Information Literacy  High Impact      High Impact
# 2         CMP 101 Computer Information Literacy  High Impact      High Impact
# 3  CMP 126 Computer Technology and Applications  High Impact      High Impact
# 4  CMP 126 Computer Technology and Applications  Some Impact      Some Impact
#
#   FACTOR: PROGRAM FACTOR: ONLINE FACTOR: REFERRAL FACTOR: STAFF  \
# 0       No Impact    Some Impact        No Impact     No Impact
# 1     High Impact            NaN      High Impact           NaN
# 2     Some Impact    Some Impact      High Impact     No Impact
# 3       No Impact      No Impact        No Impact     No Impact
# 4     Some Impact      No Impact      High Impact     No Impact
#
#   FACTOR: COLLEGE REPUTATION FACTOR: FINANCIAL AID FACTOR: SCHOLARSHIPS  ...  \
# ...

# %% [markdown]
# #### The above head function was used to confirm that the drop and rename functions were done properly and saved properly for the new datafile.

# %% [markdown]
# #### The following code saves the new datafile to the computer using a specific directory path so that it can be accessed later.

# %%
df2.to_csv("C:/Users/Jayden Mathew/Desktop/Data Science/project1_final.csv")

# %% [markdown]
# #### Import matplotlib as plt so that the analysis can include graphical data

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### The following code replaces certain values in the 'DEGREE/PROGRAM' column so that they are uniform and do not add unnecessary data for the upcoming pie chart visualization.

# %%
df2['DEGREE/PROGRAM'] = df2['DEGREE/PROGRAM'].replace({'psychology , liberal arts':'Psychology','Human Resources/ Psychology':'Psychology'})

# %% [markdown]
# #### The following code counts up the different values under the 'DEGREE/PROGRAM' column and saves it to the variable value_counts. The code then creates a figure using matplotlib that plots the value_counts variable using the different values as labels, and making the count be a percentage of 100.

# %%
value_counts = df2['DEGREE/PROGRAM'].value_counts() #This counts up the different values in the 'DEGREE/PROGRAM' column

plt.figure(figsize=(8, 8)) #Creates an 8 by 8 figure/plot
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%') #Creates a pie chart that uses the value_counts as labels, and percentagizes their counts as percents of a whole.
plt.title('Percentage of Non-Majors Backgrounds That Take Computing Classes (CCM) ')#Titles the pie chart
plt.axis('equal') #Makes the aspect ratio equal
plt.show() #Displays graph

# %% [markdown]
# ## From the data in the pie chart above, it can be analzyed that the majority of non-majors taking a computing class are majoring in Criminal Justice. This major almost holds 1/4 of non-major programmers with a percentage of 23.8%. The least populated major with students taking a computing class are Public Health, Fire Science Technologies, Music Recording, Musical Theatre, and World Language, all of which are a combined 5% of the pie chart. Using this data, CCM faculty could increase non-major computing students by focusing on opportunities for the least populated majors (listed above: Public Health, Music recording, World Language, etc.) so that they are more incentivized to learn programming.

# %% [markdown]
# #### The following code uses the isin function to sort through df2 (the updated dataframe) and isolate the values in the 'CONTINUED INTEREST (1-5)' that are between 4 and 5 due to the question prompt. Then, the code creates another variable that groups the columns that start with 'INTEREST: ' so that they can be viewed together. The next line utilizes the users who answered with a 4 or 5 and takes the count of their 'Yes' values so that they can be displayed. The rest of the code visualizes the interested counts and labels all the axises. The xticks and yticks functions are used to adjust the display of the graph so that it is more visually appealing.

# %%
interested_users = df2[df2['CONTINUED INTEREST (1-5)'].isin([4, 5])] #Saves values in the 'CONTINUED INTEREST' column to the interested_users variable if the value in this column is 4 or 5
interest_columns = [col for col in interested_users.columns if col.startswith('INTEREST: ')] #Groups all the columns that start with 'INTEREST: '
interest_yes_counts = interested_users[interest_columns].apply(lambda x: x.eq('Yes').sum()) #Takes the count of all yes values in all of the columns that begin with 'INTEREST: '

# Following code displays and visualizes the code as done previously
plt.figure(figsize=(10, 8))
interest_yes_counts.plot(kind='bar', color='lightblue') #Color is set and type of graph is set
plt.title('Computing Interests of Non-Majors Who Are Interested in Continuing Computing')
plt.xlabel('Computing Interest') #Sets an x-axis label
plt.ylabel('Count of Positve Responses') #Sets a y-axis label
plt.xticks(rotation=45, ha='right') #Rotates the tick labels on the x-axis so that they can be read
plt.yticks(range(0, 15 + 1, 1)) #Changes the tick marks on the y-axis so that they go from 0 to 15 by intervals of 1
plt.show()

# %% [markdown]
# ## From the data in the graph above, it can be seen that out of all the non-majors who are interested in continuing to learn computing at CCM, the majority (11 students) are interested in cybersecurity. This count is quickly followed by computer programming and hardware installation & repair (both of which consist of 10 students). The lowest count for interest is between web development, app development, data analytics, and game design, of which all have 8 students. Using this, CCM faculty can open more classes for the classes with higher interest counts so that they are more accessible for students who wish to continue computing.

# %% [markdown]
# #### The following code calculates the count of rows in df2 for each combination of 'Age' and 'Current Class', and then it arranges this data in a tabular format where 'Age' becomes the index, 'Current Class' becomes the columns, and the counts are the values. The rest of the code plots this tabular formatted data in a bar styled graph that uses the stacked function so that each bar can have different representations (within the bar) depending on the age range. Other features of the code are the make the graph more visually appealing and set up a legend so that the graph is better understood.

# %%
impact_counts = df2.groupby(['Age', 'Current Class']).size().unstack(fill_value=0) #Counts the rows in df2 that have a combination of 'Age' and 'Current Class' and makes this combination in a tabular format

#The following code follows the same order as the above graphs for formatting and display.
plt.figure(figsize=(8, 10))
impact_counts.T.plot(kind='bar', stacked=True, color=['red', 'purple', 'green','blue','black'])
plt.title("Distribution of Varied Ages in Respondent's Classes")
plt.xlabel('Current Class')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.yticks(range(0, 50 + 1, 5))
plt.legend(title='Age Range', bbox_to_anchor=(1, 1), loc='upper left') #This code creates a legend so that the graph is better understood, and makes the legend box located in an area that does not obstruct the view of the graph
plt.show()

# %% [markdown]
# ## From the bar graph above, it can be analyzed that for all three classes (CMP 101, CMP 126, and CMP 135) the majority of non-majors are between 19-20 years olds, which take about 50% of all classes. In contrast, CMP101 and CMP135 are least populated with 35-64 year olds, while CMP126 is least populated with students 18 and younger. Using this, CCM faculty can understand age ranges for student attending their current computing classes, and can adjust their instruction periods so that they better connect with students (For instance, younger students have shorter attention spans than adults and prefer being more hands on, while adults may take these classes after work and need more relaxed teaching styles).

# %% [markdown]
# #### The following code filters df2 to find regular expressions for columns that begin with "FACTOR: " and save these columns into a variable (factor_columns). This is a new method I found that is similar to the col.startwith() that was used in a previous graph. Next, the code takes the count of unique values in these filtered columns and saves this code to impact_counts. Then, impact_counts is transposed, meaning that the unique values are set to the rows of the tabular data, and the original values are held as the columns (making it better to visualize). The plotting code afterwards is used to set colors, style, and display the graph is the most appealing way.

# %%
factor_columns = df2.filter(regex='^FACTOR:') #Filters df2 for all columns that start with 'FACTOR: '
impact_counts = factor_columns.apply(lambda col: col.value_counts()) #Takes the count of all unique values in the factor_column variable
impact_counts = impact_counts.transpose() #Tranposes this data so that it is in tabular format where unique values are the rows and the original values are the columns

#The following code is the same as the previous graphs (any additional code will be noted)
plt.figure(figsize=(12, 8))
impact_counts.plot(kind='bar', stacked=True, color=['red', 'orange', 'green']) #The stacked function makes the data in the same columns stack on top of each other (how the impact levels are stacked)
plt.title('Influential Factors on CCM Attendees')
plt.xlabel('Factors')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout() #Displays the graph in a tigher layout so that it is more organized and appealing
plt.legend(title='Impact Level', bbox_to_anchor=(1, 1), loc='upper left')
plt.show()

# %% [markdown]
# ## The above graph shows the count of different impact levels that certain factors had on why students attended CCM. From the graph, it can be seen that the highest impacting factors were cost and location, while the lowest impacting factor was credit in highschool. CCM faculty can use this data to prioritize certain factors of CCM to increase CCM attendees. For instance, they can find ways to decrease cost or increase financial aid so that more students attend.
